# %% [markdown]
# # Installin

# %%
# %%capture
# !pip install ultralytics

# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt
from PIL import Image

# %% [markdown]
# # Training

# %%
best = "/content/drive/MyDrive/EndangeredFishDetection/YOLOv8/results/train/weights/best.pt"
# model = "/content/yolov7.pt"
data = "/content/drive/MyDrive/EndangeredFishDetection/YOLOv8/Data/data.yaml"
res = "/content/drive/MyDrive/EndangeredFishDetection/YOLOv8/results"

# %%
# !yolo detect train model={best} data={data} epochs=69 project={res}
# Out:
# Ultralytics YOLOv8.0.193 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# # Validation

# %%
best = "/content/drive/MyDrive/EndangeredFishDetection/YOLOv8/results/train/weights/best.pt"

# %% [markdown]
# # Prediction using the new model

# %%
vid = "/content/VivaCut_video_1696559543622.mp4"

res_vid = "/content/drive/MyDrive/EndangeredFishDetection/YOLOv8/res_vid"

# %%
# !yolo detect predict model="/content/drive/MyDrive/EndangeredFishDetection/YOLOv8/results/train/weights/best.pt" source={vid} conf=0.52 show_conf=false project={res_vid}
# Out:
# Ultralytics YOLOv8.0.194 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 3008573 parameters, 0 gradients, 8.1 GFLOPs
#
# video 1/1 (1/514) /content/VivaCut_video_1696559543622.mp4: 384x640 1 Scolymia-Vitiensis -Poisonous-, 168.2ms
# video 1/1 (2/514) /content/VivaCut_video_1696559543622.mp4: 384x640 1 Scolymia-Vitiensis -Poisonous-, 147.2ms
# video 1/1 (3/514) /content/VivaCut_video_1696559543622.mp4: 384x640 1 Scolymia-Vitiensis -Poisonous-, 134.9ms
# video 1/1 (4/514) /content/VivaCut_video_1696559543622.mp4: 384x640 1 Scolymia-Vitiensis -Poisonous-, 123.8ms
# video 1/1 (5/514) /content/VivaCut_video_1696559543622.mp4: 384x640 1 Scolymia-Vitiensis -Poisonous-, 128.8ms
# video 1/1 (6/514) /content/VivaCut_video_1696559543622.mp4: 384x640 1 Scolymia-Vitiensis -Poisonous-, 107.7ms
# video 1/1 (7/514) /content/VivaCut_video_1696559543622.mp4: 384x640 1 Scolymia-Vitiensis -Poisonous-, 120.1ms
# ...

# %% [markdown]
# # Export

# %%
# !yolo export model={best} format=torchscript project={res} optimize=True
# Out:
# Ultralytics YOLOv8.0.193 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 3008573 parameters, 0 gradients, 8.1 GFLOPs
#
# PyTorch: starting from '/content/drive/MyDrive/EndangeredFishDetection/YOLOv8/results/train/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 19, 8400) (6.0 MB)
#
# TorchScript: starting export with torch 2.0.1+cu118...
# TorchScript: optimizing for mobile...
# TorchScript: export success ✅ 2.4s, saved as '/content/drive/MyDrive/EndangeredFishDetection/YOLOv8/results/train/weights/best.torchscript' (11.6 MB)
#
# Export complete (4.4s)
# Results saved to /content/drive/MyDrive/EndangeredFishDetection/YOLOv8/results/train/weights
# Predict:         yolo predict task=detect model=/content/drive/MyDrive/EndangeredFishDetection/YOLOv8/results/train/weights/best.torchscript imgsz=640
# ...
